# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('../../data/raw/train.csv')
df = pd.read_pickle('../../data/processed/train.pkl')

# %%
np.random.seed(8)
df['query_index'] = np.random.choice(range(0, 800), size = df.shape[0])

# %%
get_response(url)
# Out:
# {'error_message': 'You have exceeded your daily request quota for this API.',
#  'routes': [],
#  'status': 'OVER_QUERY_LIMIT'}

# %%
import requests
# Must register an API key for Google Maps
# https://console.developers.google.com/apis/api/directions_backend/overview?project=kaggle-ny-taxi-ride-duration&duration=PT1H
def create_url(origin_lat, origin_long, dest_lat, dest_long):
    url = 'https://maps.googleapis.com/maps/api/directions/json?origin={0},{1}&destination={2},{3}&key=AIzaSyDcyKmOvmUcGWy-CIOsVZAgQ9DMCH9b43k'.format(origin_lat, origin_long, dest_lat, dest_long)
    return url

# %%
def get_response(url):
    response = requests.get(url)
    return response.json()

# %%
def get_duration_from_response(response):
    duration = response['routes'][0]['legs'][0]['duration']['value'] # units = seconds
    return duration

# %%
def get_distance_from_response(response):
    distance = response['routes'][0]['legs'][0]['distance']['value'] # units = meters
    return distance

# %%
def get_distance(origin_lat, origin_long, dest_lat, dest_long):
    url = create_url(origin_lat, origin_long, dest_lat, dest_long)
    response = get_response(url)
    distance = get_distance_from_response(response)
    return distance

# %%
def get_duration(origin_lat, origin_long, dest_lat, dest_long):
    url = create_url(origin_lat, origin_long, dest_lat, dest_long)
    response = get_response(url)
    duration = get_duration_from_response(response)
    return duration

# %%
def get_duration_and_distance(origin_lat, origin_long, dest_lat, dest_long):
    url = create_url(origin_lat, origin_long, dest_lat, dest_long)
    response = get_response(url)
    duration = get_duration_from_response(response)
    distance = get_distance_from_response(response)
    return (duration, distance)

# %%
duration = get_duration(40.767937, -73.982155,40.765602, -73.964630)
distance = get_distance(40.767937, -73.982155,40.765602, -73.964630)

# %%
def create_distance_col(df):
    for i in range(df.shape[0]):
        if df.loc[i, 'query_index'] == 0:
            df.loc[i, 'distance'] = get_distance(
                df.loc[i,'pickup_latitude'], 
                df.loc[i,'pickup_longitude'], 
                df.loc[i,'dropoff_latitude'], 
                df.loc[i,'dropoff_longitude'])
        
def create_duration_col(df):
    for i in range(df.shape[0]):
        df.loc[i,'duration'] = get_duration(
            df.loc[i,'pickup_latitude'], 
            df.loc[i,'pickup_longitude'], 
            df.loc[i,'dropoff_latitude'], 
            df.loc[i,'dropoff_longitude'])

# %%
def create_duration_and_distance_col(df):
    for i in range(2672,5000):
            df.loc[i, ['duration', 'distance']] = get_duration_and_distance(
                df.loc[i,'pickup_latitude'], 
                df.loc[i,'pickup_longitude'], 
                df.loc[i,'dropoff_latitude'], 
                df.loc[i,'dropoff_longitude'])
            print('iteration number: {}'.format(i))

# %%
df['duration'] = None
df['distance'] = None

# %%
df.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration  query_index duration  \
# ...

# %%
create_duration_and_distance_col(df)
# Out:
# iteration number: 2672
# iteration number: 2673
# iteration number: 2674
# iteration number: 2675
# iteration number: 2676
# iteration number: 2677
# iteration number: 2678
# iteration number: 2679
# iteration number: 2680
# iteration number: 2681
# iteration number: 2682
# iteration number: 2683
# iteration number: 2684
# iteration number: 2685
# iteration number: 2686
# iteration number: 2687
# iteration number: 2688
# iteration number: 2689
# iteration number: 2690
# iteration number: 2691
# iteration number: 2692
# iteration number: 2693
# iteration number: 2694
# iteration number: 2695
# iteration number: 2696
# iteration number: 2697
# iteration number: 2698
# iteration number: 2699
# iteration number: 2700
# iteration number: 2701
# iteration number: 2702
# iteration number: 2703
# iteration number: 2704
# iteration number: 2705
# iteration number: 2706
# iteration number: 2707
# iteration number: 2708
# iteration number: 2709
# iteration number: 2710
# iteration number: 2711
# ...

# %%
df[2450:2680]
# Out:
#              id  vendor_id      pickup_datetime     dropoff_datetime  \
# 2450  id0956162          1  2016-01-16 08:17:56  2016-01-16 08:25:02
# 2451  id0884032          2  2016-06-30 06:44:19  2016-06-30 06:54:05
# 2452  id2210879          1  2016-06-10 17:33:36  2016-06-10 17:41:48
# 2453  id3410374          1  2016-06-22 21:20:08  2016-06-22 21:49:43
# 2454  id2018140          1  2016-06-13 01:07:05  2016-06-13 01:10:41
# 2455  id3185408          2  2016-03-14 18:47:13  2016-03-14 18:52:57
# 2456  id1407252          1  2016-02-22 17:54:55  2016-02-22 18:29:02
# 2457  id2423857          2  2016-02-15 00:24:20  2016-02-15 00:42:43
# 2458  id3831162          2  2016-02-18 20:26:11  2016-02-18 20:27:08
# 2459  id3655653          1  2016-03-02 10:24:00  2016-03-02 10:34:03
# 2460  id3429467          1  2016-03-01 22:43:27  2016-03-01 22:49:21
# 2461  id3480786          2  2016-03-30 20:44:37  2016-03-30 21:22:18
# 2462  id3784926          1  2016-02-28 23:00:20  2016-02-28 23:08:59
# ...

# %%
create_distance_col(df)
create_duration_col(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-05f1c11cd704> in <module>()
# ----> 1 create_distance_col(df)
#       2 create_duration_col(df)
#
# <ipython-input-112-be7091b46f44> in create_distance_col(df)
#       5             df.loc[i,'pickup_longitude'],
#       6             df.loc[i,'dropoff_latitude'],
# ----> 7             df.loc[i,'dropoff_longitude'])
#       8
#       9 def create_duration_col(df):
#
# <ipython-input-71-1258c20a3c21> in get_distance(origin_lat, origin_long, dest_lat, dest_long)
#       2     url = create_url(origin_lat, origin_long, dest_lat, dest_long)
#       3     response = get_response(url)
# ----> 4     distance = get_distance_from_response(response)
#       5     return distance
#
# <ipython-input-61-93dff705bf99> in get_distance_from_response(response)
#       1 def get_distance_from_response(response):
# ...

# %%
df.shape
# Out:
# (1458644, 16)

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime'] = pd.to_datetime(df['dropoff_datetime'])

# df['pickup_weekofyear'] = df['pickup_datetime'].dt.weekofyear
df['pickup_year'] = df['pickup_datetime'].dt.year
df['pickup_month'] = df['pickup_datetime'].dt.month
df['pickup_weekday'] = df['pickup_datetime'].dt.weekday
df['pickup_day'] = df['pickup_datetime'].dt.day
df['pickup_hour'] = df['pickup_datetime'].dt.hour
df['pickup_minute'] = df['pickup_datetime'].dt.minute

# %%
df.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration  query_index duration  \
# ...

# %%
df.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# dropoff_datetime      datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# query_index                    int64
# duration                      object
# distance                      object
# pickup_year                    int64
# pickup_month                   int64
# pickup_weekday                 int64
# pickup_day                     int64
# pickup_hour                    int64
# pickup_minute                  int64
# dtype: object

# %%
print('distance: {} meters'.format(distance))
print('duration: {} seconds'.format(duration))
# Out:
# distance: 2013 meters
# duration: 473 seconds

# %%
def minutes_into_day_parts(minutes_into_day):
    if minutes_into_day < 6 * 60:
        return 'late_night'
    elif minutes_into_day < 10 * 60:
        return 'morning'
    elif minutes_into_day < 11.5 * 60:
        return 'mid_morning'
    elif minutes_into_day < 14 * 60:
        return 'lunchtime'
    elif minutes_into_day < 18 * 60:
        return 'afternoon'
    elif minutes_into_day < 20.5 * 60:
        return 'dinnertime'
    elif minutes_into_day < 23.5 * 60:
        return 'early_night'
    else:
        return 'late_night'

def prep_dates(df, date_col):
    """
    Make common date features from an input date column
    in a Pandas data frame.
  
    Attributes:
    df: A Pandas data frame
    date_col: The name of the date column represented as a string
    """
    # Avoid warnings by setting is_copy to False
    df.is_copy = False

    df[date_col] = pd.to_datetime(df[date_col])
    
    df[date_col + '_year'] = df[date_col].dt.year
    df[date_col + '_month'] = df[date_col].dt.month
    df[date_col + '_weekday'] = df[date_col].dt.weekday
    df[date_col + '_day'] = df[date_col].dt.day
    df[date_col + '_hour'] = df[date_col].dt.hour
    df[date_col + '_minute'] = df[date_col].dt.minute

    try:
        df[date_col + '_minutes_into_day'] = df[date_col].apply(lambda x: x.hour * 60 + x.minute)
    except AttributeError:
        pass

    df[date_col + '_is_weekend'] = df[date_col].apply(lambda x: x.weekday() in (5,6))
    df[date_col + '_day_part'] = df[date_col + '_minutes_into_day'].apply(minutes_into_day_parts)

    return df

# %%
df = prep_dates(df, 'pickup_datetime')

# %%
df.dtypes
# Out:
# id                                          object
# vendor_id                                    int64
# pickup_datetime                     datetime64[ns]
# dropoff_datetime                            object
# passenger_count                              int64
# pickup_longitude                           float64
# pickup_latitude                            float64
# dropoff_longitude                          float64
# dropoff_latitude                           float64
# store_and_fwd_flag                          object
# trip_duration                                int64
# query_index                                  int64
# duration                                    object
# distance                                    object
# pickup_datetime_year                         int64
# pickup_datetime_month                        int64
# pickup_datetime_weekday                      int64
# pickup_datetime_day                          int64
# ...

# %%
df.to_pickle('../../data/processed/train.pkl')
